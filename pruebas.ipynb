# %%
entrada = "15,20,40,45,20"

# %%
lista = entrada.split(',')

# %%
lista
# Out:
# ['15', '20', '40', '45', '20']

# %%
# Quiero convertir a numero los elementos de mi lista:

[float(i) for i in lista]
# Out:
# [15.0, 20.0, 40.0, 45.0, 20.0]
